# %%
import pandas as pd

# %%
pd.read_csv('data/Case_file.txt',delimiter='\t')
# Out:
#           patid  pracid  gender  birthyear   indexdate
# 0          1166     166       2       1917  02/05/2003
# 1          1633     633       2       1927  14/01/2011
# 2          2014      14       2       1922  04/04/2003
# 3          2477     477       2       1931  07/12/2009
# 4          3483     483       1       1920  20/06/2007
# 5          4383     383       2       1913  11/09/2002
# 6          4511     511       2       1920  19/04/2006
# 7          4625     625       2       1937  09/02/2012
# 8          4657     657       2       1921  13/07/2010
# 9          4670     670       2       1934  27/03/2012
# 10         5427     427       2       1920  24/05/2006
# 11         6156     156       1       1933  28/08/2011
# 12         6365     365       1       1930  11/08/2008
# 13         6579     579       1       1930  08/03/2012
# 14         6588     588       1       1926  22/05/2008
# 15         7256     256       2       1910  01/02/2002
# ...
