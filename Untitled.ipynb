# %%
import pandas as pd
from my_functions import *

# %%
create_pegprod()

# %%
pegprod = pd.read_csv('data/dicts/proc_pegasus_prod.csv',delimiter=',')

# %%
pegprod[pegprod['Product name']=='Zopiclone 3.75mg tablets (Teva UK Ltd)']
# Out:
#        Product code  XXX code  Therapy events  \
# 12785         34777  59593020             174
#
#                                  Product name Drug Substance Name  \
# 12785  Zopiclone 3.75mg tablets (Teva UK Ltd)           Zopiclone
#
#       Substance strength Formulation Route  BNF code BNF header  \
# 12785             3.75mg      Tablet  Oral  04010100  Hypnotics
#
#       Database Build Unknown column
# 12785  February 2009       02923009

# %%
pegprod
# Out:
#        Product code  XXX code  Therapy events  \
# 0             28484  95866020             189
# 1             25421  72087020               2
# 2             44704  04001021               3
# 3             46912  61115020               3
# 4              4830  69185020           55401
# 5             30990  61163020             115
# 6              7663  01237007            1537
# 7              4860  76749020             882
# 8             30109  06777007               4
# 9             36565  01432007               9
# 10            32321  68851020              71
# 11            54124  46363020             237
# 12            50240  23588020              52
# 13            20816  04385007              13
# 14             7714  04189007             250
# 15            32020  54496020               1
# 16            52444  08842020               1
# 17            51292  21264020               0
# 18            55610  10787021               5
# ...
