# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from data_processing import *

# %%
from import_file import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
# Out:
# <style>.container { width:98% !important; }</style>

# %%
pt_features=pd.read_csv('data/pt_data/pt_features.csv',delimiter=',')

# %%
# pt_features

# %%
pegmed = pd.read_csv('data/dicts/proc_pegasus_medical.csv',delimiter=',',usecols=['medcode','read term'])

# %%
pt_features = pd.merge(pt_features,pegmed,how='left',left_on='final dementia medcode',right_on='medcode')

# %%
pt_features[(pt_features['insom_count']>0) & (pt_features['isCase']==True)]
# Out:
#          patid  gender   yob  pracid  index_date isCase  \
# 72    12227247       1  1929     247  2009-09-11   True
# 77    12853133       1  1935     133  2011-02-24   True
# 95      720056       2  1923      56  2008-11-25   True
# 106    2896270       2  1920     270  2008-02-01   True
# 126    1095155       2  1939     155  2011-01-25   True
# 186   17581438       2  1919     438  2009-01-27   True
# 189    2064021       2  1932      21  2010-10-14   True
# 375    3742322       2  1932     322  2008-07-23   True
# 381    6249309       1  1926     309  2009-11-17   True
# 479    8590190       2  1932     190  2010-07-16   True
# 485    4037190       2  1928     190  2010-09-29   True
# 491    8851174       2  1932     174  2009-07-15   True
# 519     670190       2  1929     190  2010-09-13   True
# 553    6523194       2  1924     194  2009-06-01   True
# 618    9246398       1  1920     398  2010-01-28   True
# 745    2479303       2  1921     303  2008-12-23   True
# ...

# %%
all_cases = len(pt_features)
all_cases
# Out:
# 3356

# %%
len(pt_features[(pt_features['insom_count']>0) & pt_features['isCase']==True])
# Out:
# 96

# %%
len(pt_features[(pt_features['insom_count']>0) & (pt_features['isCase']==False)])
# Out:
# 74
