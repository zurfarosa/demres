# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport my_functions
# %aimport csv_creator_functions
# %aimport codelists
# %aimport constants

# %%
import pandas as pd
from my_functions import *
from matching_functions import *
from csv_creator_functions import *
import codelists
import constants
import datetime

# %%
# pd.options.display.max_rows = 5000

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
matching_unmatched_removed = pd.read_csv('data/pt_data/matching_unmatched_removed.csv',delimiter=',',parse_dates=True,infer_datetime_format=True,dayfirst=True)

# %%
matching_unmatched_removed[matching_unmatched_removed['case_patid']==5201030]
# Out:
#        case_patid  case_pracid  case_gender  case_birthyear  case_index  \
# 24004     5201030           30            2            1935  2009-05-11
#
#        match  control_patid  control_pracid  control_gender  \
# 24004      1        2992030              30               2
#
#        control_birthyear control_start control_end
# 24004               1935    01/01/2000  01/06/2012

# %%
create_pt_features()

# %%
pt_features = pd.read_csv('data/pt_data/pt_features.csv',delimiter=',',parse_dates=['index_date'],infer_datetime_format=True)

# %%
pt_features[pt_features['patid']==5201030]
# Out:
#          patid  pracid  gender  birthyear index_date isCase
# 24004  5201030      30       2       1935 2009-05-11   True

# %%
pt_features['index_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
presc1 = pd.read_csv('data/pt_data/Extract_Therapy_001.txt',delimiter='\t',usecols=['patid','sysdate','eventdate','prodcode','qty','ndd','numdays','numpacks','packtype','issueseq'],parse_dates=['sysdate','eventdate'],infer_datetime_format=True,dayfirst=True)

# %%
presc1.head(5)
# Out:
#    patid   eventdate    sysdate  prodcode    qty   ndd  numdays  numpacks  \
# 0  57001  08/02/1989 1997-03-08       807   50.0   2.0        0       0.0
# 1  57001  20/02/1989 1997-03-08      2322  300.0  60.0        0       0.0
# 2  57001  27/02/1989 1997-03-08      2322  300.0   0.0        0       0.0
# 3  57001  09/05/1989 1997-03-08        44   30.0   0.0        0       0.0
# 4  57001  10/07/1989 1997-03-08        79   10.0   4.0        0       0.0
#
#    packtype  issueseq
# 0         0         0
# 1         6         0
# 2         6         0
# 3         0         0
# 4         6         0

# %%
presc1['eventdate'].dtype
# Out:
# dtype('O')

# %%
presc1_not_parsed = pd.read_csv('data/pt_data/Extract_Therapy_001.txt',delimiter='\t',usecols=['patid','sysdate','eventdate','prodcode','qty','ndd','numdays','numpacks','packtype','issueseq'])

# %%
presc1_not_parsed.head(5)
# Out:
#    patid   eventdate     sysdate  prodcode    qty   ndd  numdays  numpacks  \
# 0  57001  08/02/1989  08/03/1997       807   50.0   2.0        0       0.0
# 1  57001  20/02/1989  08/03/1997      2322  300.0  60.0        0       0.0
