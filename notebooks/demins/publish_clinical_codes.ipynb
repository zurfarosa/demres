# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ~/demres
# Out:
# /Users/zurfarosa/demres

# %%
import os, sys, re

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
from datetime import date, timedelta

import demres
from demres.common import codelists,druglists

# %%
pd.set_option('display.max_columns', None)

# %%
codelists
# Out:
# <module 'demres.common.codelists' from '/Users/zurfarosa/demres/common/codelists.py'>

# %%
condition_df = pd.DataFrame(columns=['code','coding_system','description'])

# %%
condition_df
# Out:
# Empty DataFrame
# Columns: [code, coding_system, description]
# Index: []

# %%
for row,code in enumerate(codelists.epilepsy['codes']):
    condition_df.loc[row,'code']=code
    condition_df.loc[row,'description']=code
# Out:
# [autoreload of demres.common.codelists failed: Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/zurfarosa/demres/common/codelists.py", line 1889
#     'F257.00':'Kojevnikov's epilepsy',
#                           ^
# SyntaxError: invalid syntax
# ]

# %%
condition_df
# Out:
#         code coding_system description
# 0       1473           NaN         NaN
# 1    1B1W.00           NaN         NaN
# 2    1O30.00           NaN         NaN
# 3       2823           NaN         NaN
# 4       2824           NaN         NaN
# 5    2824.11           NaN         NaN
# 6       2825           NaN         NaN
# 7       2828           NaN         NaN
# 8    667B.00           NaN         NaN
# 9    667N.00           NaN         NaN
# 10   Eu05212           NaN         NaN
# 11   Eu05y11           NaN         NaN
# 12   Eu06013           NaN         NaN
# 13   F132100           NaN         NaN
# 14   F132200           NaN         NaN
# 15   F25..00           NaN         NaN
# 16   F250.00           NaN         NaN
# 17   F250000           NaN         NaN
# 18   F250011           NaN         NaN
# 19   F250100           NaN         NaN
# 20   F250200           NaN         NaN
# 21   F250300           NaN         NaN
# 22   F250y00           NaN         NaN
# ...
