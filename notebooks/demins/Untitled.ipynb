# %%
import pandas as pd

# %%
cd ~/demres/
# Out:
# /Users/zurfarosa/demres

# %%
df = pd.read_csv('data/dicts/proc_pegasus_medical.csv',delimiter=',')

# %%
df.columns
# Out:
# Index(['medcode', 'readcode', 'clinical events', 'immunisation events',
#        'referral events', 'test events', 'read term', 'database build'],
#       dtype='object')

# %%
df.loc[df['read term'].str.contains('inflam',case=False,na=False)]
# Out:
#         medcode readcode  clinical events  immunisation events  \
# 721       25557  J064.00               69                    0
# 1407      72938  K41z.00                3                    0
# 1483       3471  4K3..00             5315                    0
# 2138       6913  TJ56.11             3049                    0
# 2910      59595  F4H1200                3                    0
# 4014       6068  K28X.00               28                    0
# 5541      94334  1JG..00             2276                    0
# 5904      35726  J064z00               34                    0
# 7600      14719  M1z..00             6037                    0
# 8393      26457  K284.00              427                    0
# 8539     101554  FyuB000                2                    0
# 8768      42352  5B11.00                1                    0
# 9106      67869  F4G1.00                9                    0
# 9295      97660  Fyu0.00                3                    0
# ...
