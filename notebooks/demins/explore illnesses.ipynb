# %%
# %load_ext autoreload
# %autoreload 2

# %%
cd ~/demres
# Out:
# /Users/zurfarosa/demres

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
from datetime import date, timedelta
from pprint import pprint

import demres
from demres.common.constants import entry_type
from demres.common import codelists
from demres.common.helper_functions import *
from demres.demins.constants import Study_Design
from demres.demins.functions import *

# %%
pegmed = pd.read_csv('data/dicts/proc_pegasus_medical.csv',delimiter=',')

# %%
pegmed.head(1)
# Out:
#    medcode readcode  clinical events  immunisation events  referral events  \
# 0    42602  E001000               30                    0                1
#
#    test events                         read term database build
# 0            0  Uncomplicated presenile dementia  February 2009

# %%
pegmed.loc[pegmed['read term'].str.contains('units',regex=True,na=False,case=False),['medcode','clinical events','readcode','read term']]
# Out:
#        medcode  clinical events readcode  \
# 44609    97126             3977  136X.00
# 84264    93415            28485  136V.00
#
#                                              read term
# 44609  Alcohol units consumed on heaviest drinking day
# 84264                           Alcohol units per week

# %%
pegprod = pd.read_csv('data/dicts/proc_pegasus_prod.csv')

# %%
pegprod.head(1)
# Out:
#    prodcode  XXX code  therapy events  \
# 0     28484  95866020             189
#
#                                         product name  drug substance name  \
# 0  Physiotulle Ag dressing 10cm x 10cm (Coloplast...  Silver Sulfadiazine
#
#   substance strength formulation route  BNF code  \
# 0        10cm X 10cm    Dressing   NaN  72214100
#
#                                           BNF header database build  \
# 0  Soft Polymer Wound Contact Dressing Impregnate...  February 2009
#
#   unknown column
# 0       16545005

# %%
pegprod.loc[pegprod['drug substance name'].str.contains('cpa*',regex=True,na=False,case=False)]
# Out:
# Empty DataFrame
# Columns: [prodcode, XXX code, therapy events, product name, drug substance name, substance strength, formulation, route, BNF code, BNF header, database build, unknown column]
# Index: []

# %%
tests = pd.read_csv('data/pt_data/raw_data/Extract_Test_001.txt',delimiter='\t')

# %%
mcvs = tests[tests['medcode']==93415]

# %%
mcvs
# Out:
# Empty DataFrame
# Columns: [patid, eventdate, sysdate, constype, consid, medcode, staffid, textid, enttype, data1, data2, data3, data4, data5, data6, data7, data8]
# Index: []

# %%
entries = pd.read_hdf('hdf/medcoded_entries.hdf')

# %%
entries[entries['medcode']==93415]
# Out:
#              patid  eventdate    sysdate  medcode  type
# 2100736     333051 2012-11-15 2012-11-15    93415     2
# 2101939     501051 2011-12-12 2012-02-07    93415     2
# 2101944     501051 2012-08-02 2012-08-02    93415     2
# 2130068    3142051 2012-07-20 2012-07-20    93415     2
# 2147218    4937051 2012-09-12 2012-09-12    93415     2
# 2147964    5001051 2012-03-26 2012-03-26    93415     2
# 2159434    6289051 2012-11-23 2012-11-23    93415     2
# 2160728    6596051 2012-11-21 2012-11-21    93415     2
# 2191605    9730051 2012-07-30 2012-07-30    93415     2
# 2224479   12384051 2009-05-19 2009-05-19    93415     2
# 2224484   12384051 2010-04-20 2010-04-20    93415     2
# 2224492   12384051 2011-04-26 2012-03-08    93415     2
# 2224494   12384051 2012-08-07 2012-08-07    93415     2
# 2225008   12385051 2012-03-21 2012-03-21    93415     2
# 2225012   12385051 2012-07-25 2012-07-25    93415     2
# 2227967   12696051 2012-08-02 2012-08-02    93415     2
# ...

# %%
ss
