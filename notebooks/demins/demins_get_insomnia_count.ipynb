# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ~/demres
# Out:
# /Users/zurfarosa/demres

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd
import numpy as np
from datetime import date, timedelta

import demres
from demres.common.constants import entry_type
from demres.common import codelists
from demres.common.helper_functions import *
from demres.common.process_raw_data import *
from demres.demins.constants import Study_Design
from demres.demins.functions import get_insomnia_event_count

# %%
pt_features = pd.read_csv('data/pt_data/processed_data/pt_features_demins.csv',delimiter=',',parse_dates=['index_date','data_end','data_start'],infer_datetime_format=True)

# %%
pt_features.head(3)
# Out:
#       patid  gender   yob  pracid index_date isCase  final dementia medcode  \
# 0  12440330       2  1925     330 2010-03-30   True                  4693.0
# 1  16055443       2  1927     443 2010-12-20   True                  1350.0
# 2   2994148       2  1919     148 2007-02-15   True                  1916.0
#
#   data_start   data_end  matchid
# 0 2000-03-22 2010-04-09  50163.0
# 1 2000-12-15 2011-01-13  65618.0
# 2 1997-01-20 2007-02-21  21685.0

# %%
pt_features.data_end.dtype
# Out:
# dtype('<M8[ns]')

# %%
medcoded_entries = pd.read_hdf('hdf/medcoded_entries.hdf')

# %%
medcoded_entries.head(3)
# Out:
#    patid  eventdate    sysdate  medcode  type
# 0  57001 1994-10-31 1997-03-09     3550     2
# 1  57001 1994-10-31 1997-03-09     9897     2
# 2  57001 1993-01-28 1997-03-09     4447     2

# %%
medcoded_entries.sysdate.dtype
# Out:
# dtype('<M8[ns]')

# %%
entries = medcoded_entries

# %%
pt_features.head(3)
# Out:
#       patid  gender   yob  pracid index_date isCase  final dementia medcode  \
# 0  12440330       2  1925     330 2010-03-30   True                  4693.0
# 1  16055443       2  1927     443 2010-12-20   True                  1350.0
# 2   2994148       2  1919     148 2007-02-15   True                  1916.0
#
#   data_start   data_end  matchid
# 0 2000-03-22 2010-04-09  50163.0
# 1 2000-12-15 2011-01-13  65618.0
# 2 1997-01-20 2007-02-21  21685.0

# %%
# Create list of all insomnia entries, then group it to calculate each patient's insomnia count, broken down by month
insomnia_medcodes = get_medcodes_from_readcodes(codelists.insomnia_readcodes)
insom_events = entries[entries['medcode'].isin(insomnia_medcodes)]
insom_events = insom_events[pd.notnull(insom_events['eventdate'])] #drops a small number of rows (only about 64) with NaN eventdates
insom_events = insom_events[['patid','eventdate']].set_index('eventdate').groupby('patid').resample('M').count()
#convert group_by object back to dataframe
insom_events = insom_events.add_suffix('_count').reset_index()
insom_events.columns=['patid','eventdate','insom_count']
#delete zero counts
insom_events = insom_events[insom_events['insom_count']>0]
insom_events = pd.merge(insom_events,pt_features,how='inner')[['patid','eventdate','insom_count','index_date']]

# %%
insom_events.head(3)
# Out:
#    patid  eventdate  insom_count index_date
# 0   4657 1997-01-31            1 2010-07-13
# 1   4657 1998-12-31            1 2010-07-13
# 2   8667 1996-10-31            1 2009-10-26

# %%
for window_count,window in enumerate(get_windows()):
    window_insom_events = insom_events
    window_count = str(window_count)
    print(window_count)
    # Restrict insomnia event counts to those that occur during exposure window
    relevant_event_mask = (window_insom_events['eventdate']<=(window_insom_events['index_date']-window['start_latency'])) & (window_insom_events['eventdate']>=(window_insom_events['index_date']-window['end_latency']))
    window_insom_events = window_insom_events.loc[relevant_event_mask]
    window_insom_events = window_insom_events.groupby('patid')['insom_count'].count().reset_index()
    window_insom_events.columns=['patid','insom_count_window'+window_count]
#     merge pt_features with new insomnia_event dataframe
    pt_features = pd.merge(pt_features,window_insom_events,how='left')
    pt_features['insom_count_window'+window_count].fillna(0,inplace=True)
    pt_features['insom_count_window'+window_count] = pt_features['insom_count_window'+window_count].astype(int)
# Out:
# 0
# 1
# 2

# %%
pt_features.head(3)
# Out:
#       patid  gender   yob  pracid index_date isCase  final dementia medcode  \
# 0  12440330       2  1925     330 2010-03-30   True                  4693.0
# 1  16055443       2  1927     443 2010-12-20   True                  1350.0
# 2   2994148       2  1919     148 2007-02-15   True                  1916.0
#
#   data_start   data_end  matchid  insom_count_window0  insom_count_window1  \
# 0 2000-03-22 2010-04-09  50163.0                    0                    0
# 1 2000-12-15 2011-01-13  65618.0                    0                    0
# 2 1997-01-20 2007-02-21  21685.0                    0                    1
#
#    insom_count_window2
# 0                    0
# 1                    0
# 2                    1

# %%
# pt_features = pt_features.drop(['insom_count_window0','insom_count_window1'],axis=1)

# %%
pt_features.sort_values(by='insom_count_window0',ascending=False)
# Out:
#           patid  gender   yob  pracid index_date isCase  \
# 7712    6762193       2  1917     193 2009-02-05  False
# 9452    5114043       2  1916      43 2008-11-08   True
# 413     2287025       2  1944      25 2011-03-22   True
# 10778   5842194       2  1939     194 2010-05-06   True
# 12518   8291322       2  1921     322 2009-10-08  False
# 6950    1570199       1  1928     199 2006-07-11   True
# 2424   10871398       2  1919     398 2009-04-21   True
# 8534     199159       2  1931     159 2009-03-30   True
# 3623     179091       1  1934      91 2006-06-15   True
# 6660   11218031       2  1920      31 2009-03-02  False
# 11495   2477115       2  1922     115 2010-10-10  False
# 10492   5302444       1  1920     444 2010-11-22   True
# 7578     594441       2  1919     441 2008-08-28  False
# 8320    7683322       2  1915     322 2009-04-23  False
# 10150   3691174       2  1923     174 2010-03-02  False
# 2771    3909084       2  1928      84 2010-01-04  False
# 2136    9319411       1  1921     411 2006-12-08   True
# 11927   4388383       2  1918     383 2009-06-03  False
# 6949    2611190       2  1925     190 2010-11-26  False
# 10707   8163031       1  1923      31 2010-03-02  False
# 9192    3206404       2  1922     404 2010-03-24  False
# 2196    1822025       2  1924      25 2011-04-07  False
# 77     12229411       2  1939     411 2006-12-22   True
# 1977    4057205       2  1921     205 2010-02-16   True
# 8232     604441       1  1924     441 2010-11-03   True
# 501    34138465       1  1929     465 2007-11-12   True
# 11549   4875270       2  1921     270 2009-09-14   True
# 876     7693166       2  1926     166 2008-04-09   True
# 3864    1673606       2  1929     606 2011-01-17   True
# 9114    2328359       2  1927     359 2008-06-06   True
# ...         ...     ...   ...     ...        ...    ...
# 4468    7745389       2  1927     389 2009-11-01  False
# 4469    9520639       2  1917     639 2010-05-04  False
# 4470   10237639       1  1922     639 2010-04-07   True
# 4471    1166206       1  1931     206 2010-04-19  False
# 4473    8649639       2  1917     639 2010-05-04   True
# 4474    5154087       2  1925      87 2009-03-04   True
# 4450    9289206       2  1920     206 2010-10-07  False
# 4449    1689223       2  1922     223 2009-04-30  False
# 4448    3220565       2  1923     565 2010-02-14   True
# 4447    1729223       2  1937     223 2010-08-13   True
# 4426    1727089       1  1925      89 2011-01-24   True
# 4427    2445321       1  1924     321 2007-05-16  False
# 4428    2815203       2  1931     203 2011-04-06   True
# 4429    2160389       2  1927     389 2008-08-21   True
# 4430    9955374       2  1939     374 2010-11-04   True
# 4431    9071639       2  1925     639 2010-10-01  False
# 4432   11395164       1  1926     164 2006-07-07  False
# 4431                      NaN 1999-06-22 2013-04-15  89207.0
# 4432                      NaN 1996-05-13 2010-03-08  24146.0
# 4433                   4693.0 1996-02-02 2009-11-27   3236.0
# 4434                      NaN 1999-05-24 2013-03-18  90609.0
# 4436                      NaN 1999-01-25 2012-11-19  33911.0
# 4437                   6578.0 1998-01-07 2011-11-02  41934.0
# 4438                      NaN 1999-06-22 2013-04-16  89186.0
# 4439                   1350.0 1997-07-25 2011-05-20  12428.0
# 4440                      NaN 1997-03-25 2011-01-18  18926.0
# 4441                   8195.0 1999-06-16 2013-04-10  30943.0
# 4442                      NaN 1997-12-17 2011-10-13  49579.0
# 4443                      NaN 1999-06-16 2013-04-11  30968.0
# 4445                   6578.0 1999-01-25 2012-11-20  33903.0
# 4446                   7664.0 1999-01-25 2012-11-20  34015.0
# 12735                  1350.0 1994-12-09 2013-05-21  50892.0
#
#        insom_count_window0  insom_count_window1  insom_count_window2
# 7712                    27                    1                    0
# 9452                    11                    0                    0
# 413                      9                    0                    0
# 10778                    9                    7                    2
# 12518                    9                   28                   21
# 6950                     6                    5                    1
# 2424                     6                    0                    0
# 8534                     6                    3                    1
# 3623                     5                    2                   11
# 6660                     5                    3                    0
# 11495                    5                    4                    1
# 10492                    5                    0                    0
# 7578                     5                    2                    2
# 8320                     5                    0                    0
# 10150                    5                    3                    0
# 2771                     5                    1                    0
# 2136                     5                    1                    0
# 11927                    4                    2                    3
# 6949                     4                    0                    0
# 10707                    4                    0                    0
# 9192                     4                    2                    4
# 2196                     4                    0                    0
# 77                       4                    0                    0
# 1977                     4                    1                    1
# 8232                     4                    0                    0
# 501                      4                    1                    0
# 11549                    4                    5                    0
# 876                      4                    3                    1
# 3864                     4                    0                    0
# 9114                     4                    1                    0
# ...                    ...                  ...                  ...
# 4468                     0                    0                    0
# 4469                     0                    0                    0
# 4470                     0                    0                    0
# 4471                     0                    0                    0
# 4473                     0                    0                    0
# 4474                     0                    0                    0
# 4450                     0                    0                    0
# 4449                     0                    0                    0
# 4448                     0                    4                    1
# 4447                     0                    0                    1
# 4426                     0                    0                    0
# 4427                     0                    0                    0
# 4428                     0                    0                    0
# 4429                     0                    0                    1
# 4430                     0                    0                    0
# 4431                     0                    0                    0
# 4432                     0                    0                    0
# 4433                     0                    0                    0
# 4434                     0                    0                    0
# 4436                     0                    0                    0
# 4437                     0                    1                    1
# 4438                     0                    0                    0
# 4439                     0                    0                    0
# 4440                     0                    0                    0
# 4441                     0                    0                    0
# 4442                     0                    0                    0
# 4443                     0                    0                    0
# 4445                     0                    0                    0
# 4446                     0                    0                    1
# 12735                    0                    0                    0
#
# [12736 rows x 13 columns]

# %%
cases = pt_features[pt_features['isCase']==True]

# %%
controls = pt_features[pt_features['isCase']==False]

# %%
cases['insom_count_window0'].mean()
# Out:
# 0.13300879396984924

# %%
controls['insom_count_window0'].mean()
# Out:
# 0.12060301507537688

# %%
cases['insom_count_window1'].mean()
# Out:
# 0.13159547738693467

# %%
controls['insom_count_window1'].mean()
# Out:
# 0.11652010050251256

# %%
cases['insom_count_window2'].mean()
# Out:
# 0.12327261306532664

# %%
controls['insom_count_window2'].mean()
# Out:
# 0.096262562814070349

# %%
len(cases),len(controls)
# Out:
# (6368, 6368)

# %%
pt_features.to_csv('data/pt_data/processed_data/pt_features_demins.csv',index=False)
