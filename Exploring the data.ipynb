# %%
import pandas as pd
from my_functions import *

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
pt_features = pd.read_csv('data/pt_data/pt_features.csv',delimiter=',',parse_dates=['index_date'])

# %%
pt_features[pt_features['insomnia_event_count']>0].sort_values(by='insomnia_event_count',ascending=False)
# Out:
#           patid  pracid  gender  birthyear index_date isCase earliest_sysdate  \
# 11403   6762193     193       2       1917 2009-05-02  False       1997-11-14
# 10661   8291322     322       2       1921 2008-07-02  False       1995-09-21
# 5799    5842194     194       2       1939 2010-06-05   True       1996-08-09
# 1173    1570199     199       1       1928 2006-11-07   True       1996-05-12
# 4659    5114043      43       2       1916 2008-08-11   True       1996-01-05
# 2039    2287025      25       2       1944 2011-03-22   True       2000-04-27
# 8784    2124315     315       2       1921 2011-01-31  False       1999-11-26
# 4748   17217653     653       2       1924 2010-01-12   True       1997-05-10
# 5856    2831336     336       2       1928 2010-08-12   True       1996-09-25
# 6336    4398431     431       2       1927 2011-04-05   True       1996-07-25
# 6998   15936005       5       2       1920 2008-04-07  False       1997-11-21
# ...

# %%
pt_features[pt_features['isCase']==True].loc[:,'insomnia_event_count'].mean()
# Out:
# 0.11076732673267327

# %%
pt_features[pt_features['isCase']==False].loc[:,'insomnia_event_count'].mean()
# Out:
# 0.085396039603960402

# %%
pt_features[(pt_features['isCase']==True)&(pt_features['insomnia_event_count']>0)].count()
# Out:
# patid                   418
# pracid                  418
# gender                  418
# birthyear               418
# index_date              418
# isCase                  418
# earliest_sysdate        418
# latest_sysdate          418
# days_pre_indexdate      418
# days_post_indexdate     418
# matchid                 418
# insomnia_event_count    418
# dtype: int64

# %%
pt_features[(pt_features['isCase']==False)&(pt_features['insomnia_event_count']>0)].count()
# Out:
# patid                   327
# pracid                  327
# gender                  327
# birthyear               327
# index_date              327
# isCase                  327
# earliest_sysdate        327
# latest_sysdate          327
# days_pre_indexdate      327
# days_post_indexdate     327
# matchid                 327
# insomnia_event_count    327
# dtype: int64

# %%
418/(12928/2)*100
# Out:
# 6.466584158415841

# %%
327/(12928/2)*100
# Out:
# 5.058787128712872
