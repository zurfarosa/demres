# %%
import pandas as pd

# %%
pd.read_csv('data/pt_data/Extract_Therapy_001.txt',delimiter='\t').head(15)
# Out:
#     patid   eventdate     sysdate  consid  prodcode  staffid  textid  bnfcode  \
# 0   57001  08/02/1989  08/03/1997    9457       807        0       4        4
# 1   57001  20/02/1989  08/03/1997    9458      2322        0    1236      231
# 2   57001  27/02/1989  08/03/1997    9447      2322        0    1457      231
# 3   57001  09/05/1989  08/03/1997    9448        44        0       2      102
# 4   57001  10/07/1989  08/03/1997    9459        79        0      26        2
# 5   57001  07/08/1989  08/03/1997    9449      1559        0  100079      185
# 6   57001  25/08/1989  08/03/1997    9460      1559        0      76      185
# 7   57001  21/09/1989  08/03/1997    9461      1559        0  100080      185
# 8   57001  10/11/1989  08/03/1997    9450      1559     9001  100081      185
# 9   57001  10/11/1989  08/03/1997    9450      2322     9001    1457      231
# 10  57001  09/07/1990  08/03/1997    9462      1559     6001  100080      185
# ...

# %%
pd.read_csv('data/pt_data/Extract_Test_001.txt',delimiter='\t').head(5)
# Out:
#    patid   eventdate     sysdate  constype  consid  medcode  staffid  textid  \
# 0  57001  31/10/1994  09/03/1997         2    9455     3668        0       0
# 1  57001  28/07/1994  09/03/1997         2    9475     5717        0       0
# 2  57001  31/10/1994  09/03/1997         2    9455     3389        0     156
# 3  57001  11/03/2005  11/03/2005         2    9583    14456   159001       0
# 4  57001  21/07/1994  16/07/1999         2    9489       55    52001       0
#
#    enttype  data1  data2  data3  data4  data5  data6  data7  data8
# 0      274      0    9.0    0.0      0    NaN    NaN    0.0    NaN
# 1      275      0    7.3    0.0      0    NaN    NaN    0.0    NaN
# 2      288      0    NaN    0.0      0    NaN    NaN    0.0    NaN
# 3      395      3   72.0    1.0      0    NaN    NaN    0.0    NaN
# 4      213      3   15.9   96.0      0    NaN    NaN    0.0    NaN

# %%
pd.read_csv('data/pt_data/Extract_Referral_001.txt',delimiter='\t').head(5)
# Out:
#    patid   eventdate     sysdate  constype  consid  medcode  staffid  textid  \
# 0  57001  31/10/1994  09/03/1997         4    9455     3389        0       0
# 1  57001  28/07/1994  09/03/1997         4    9475     5717        0       0
# 2  57001  31/10/1994  09/03/1997         4    9455     3668        0       0
# 3  57001  09/12/2004  09/12/2004         4    9575     2906     9001       0
# 4  57001  19/09/2007  19/09/2007         4    9667    12479   113001      26
#
#    source  nhsspec  fhsaspec  inpatient  attendance  urgency
# 0       0        0        16          3           0        0
# 1       0        0        16          3           0        0
# 2       0        0        16          3           0        0
# 3       1       16         2          0           0        2
# 4       1        0         2          3           0        4

# %%
pd.read_csv('data/pt_data/Extract_Practice_001.txt',delimiter='\t').head(10)
# Out:
#    pracid  region         lcd         uts
# 0       1       8  21/05/2013  07/09/1999
# 1       2      13  09/05/2013  16/03/2000
# 2       3       8  23/05/2013  06/09/2001
# 3       4      11  08/04/2013  07/01/1991
# 4       5       6  02/09/2010  27/03/1995
# 5       6       7  20/04/2013  18/11/1989
# 6       7       2  05/03/2002  22/08/1989
# 7       8      12  08/03/2002  31/08/1990
# 8       9      12  05/05/2009  08/08/2000
# 9      10       9  07/05/2013  09/01/2007

# %%
pd.read_csv('data/pt_data/Extract_Patient_001.txt',delimiter='\t').head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     patid   vmid  gender  yob  mob  marital  famnum  chsreg chsdate  prescr  \
# 0   57001   1682       1  132    0        2     730       2     NaN       0
# 1   60001   3405       1  124    0        6    1475       2     NaN       4
# 2  149001   3238       2  119    0        6    1398       2     NaN       3
# 3  364001  13436       2  137    0        2    6628       2     NaN       0
# 4  432001   4006       2  120    0        6    1726       2     NaN       3
#
#    ...    ses         frd         crd regstat  reggap  internal         tod  \
# 0  ...      0  10/05/1977  10/05/1977       0       0         0         NaN
# 1  ...      0  11/03/1988  11/03/1988       0       0         0         NaN
# ...

# %%
pd.read_csv('data/pt_data/Extract_Immunisation_001.txt',delimiter='\t').head(3)
# Out:
#    patid   eventdate     sysdate  constype  consid  medcode  staffid  textid  \
# 0  57001  04/06/1991  09/03/1997         4    9473    14599        0       0
# 1  57001  04/06/1991  09/03/1997         4    9473    14582        0       0
# 2  57001  10/01/2001  31/01/2001         4    9506        6     9001       0
#
#    immstype  stage  status  compound  source  reason  method
# 0        24      1       1         0       4       0       0
# 1        12      1       1         0       4       0       0
# 2         4      5       1         0       1       3       1

# %%
pd.read_csv('data/pt_data/Extract_Consultation_001.txt',delimiter='\t').head(5)
# Out:
#    patid   eventdate     sysdate  constype  consid  staffid  duration
# 0  57001  11/06/1991  07/03/1997        15    9444     9001         0
# 1  57001  19/11/1990  07/03/1997         9    9445     9001         0
# 2  57001  01/01/1986  07/03/1997        15    9446        0         0
# 3  57001  27/02/1989  07/03/1997         9    9447     9001         0
# 4  57001  09/05/1989  07/03/1997         9    9448     9001         0

# %%
pd.read_csv('data/pt_data/Extract_Clinical_001.txt',delimiter='\t').head(5)
# Out:
#    patid   eventdate     sysdate  constype  consid  medcode  staffid  textid  \
# 0  57001  31/10/1994  09/03/1997         4    9455     3550     9001       0
# 1  57001  31/10/1994  09/03/1997         5    9455     9897     9001       0
# 2  57001  28/01/1993  09/03/1997         2    9474     4447        0       0
# 3  57001  28/01/1993  09/03/1997         2    9474        3        0       0
# 4  57001  28/01/1993  09/03/1997         2    9474       60        0       0
#
#    episode  enttype  adid
# 0        0       26  1690
# 1        0       65  1691
# 2        0        5  1692
# 3        0       14  1693
# 4        0        4  1694

# %% [markdown]
# medcode n

# %%
pd.read_csv('data/pt_data/Extract_Additional_001.txt',delimiter='\t').head(5)
# Out:
#    patid  enttype  adid  data1  data2  data3  data4  data5  data6  data7
# 0  57001       26  1690   1.00    NaN    NaN    NaN    NaN    NaN    NaN
# 1  57001       65  1691   0.00    NaN    NaN    NaN    NaN    NaN    NaN
# 2  57001        5  1692   2.00    NaN    0.0    0.0    NaN    NaN    NaN
# 3  57001       14  1693   1.22    0.0    NaN    NaN    NaN    NaN    NaN
# 4  57001        4  1694   2.00    NaN    NaN    NaN    0.0    0.0    NaN

# %%
pd.read_csv('data/pt_data/Extract_Additional_001.txt',delimiter='\t').head(5)
# Out:
#    patid  enttype  adid  data1  data2  data3  data4  data5  data6  data7
# 0  57001       26  1690   1.00    NaN    NaN    NaN    NaN    NaN    NaN
# 1  57001       65  1691   0.00    NaN    NaN    NaN    NaN    NaN    NaN
# 2  57001        5  1692   2.00    NaN    0.0    0.0    NaN    NaN    NaN
# 3  57001       14  1693   1.22    0.0    NaN    NaN    NaN    NaN    NaN
# 4  57001        4  1694   2.00    NaN    NaN    NaN    0.0    0.0    NaN

# %%
pd.read_csv('data/pt_data/Matching_File.txt',delimiter='\t').head(5)
# Out:
#    case_patid  case_pracid  case_gender  case_birthyear  case_index  match  \
# 0     4923328          328            2            1916  01/07/2003      1
# 1     1959216          216            1            1933  25/02/2011      1
# 2     9271420          420            1            1917  20/06/2003      1
# 3      548429          429            2            1925  11/05/2005      1
# 4    14185081           81            2            1917  28/02/2005      1
#
#   control_patid control_pracid control_gender control_birthyear control_start  \
# 0       4355328            328              2              1916    01/01/2000
# 1       6290216            216              1              1933    01/01/2000
# 2       2770420            420              1              1917    02/01/2003
# 3       5473429            429              2              1925    01/01/2000
# 4       5951081             81              2              1917    01/01/2000
#
#   control_end
# 0  07/02/2009
# 1  01/06/2012
# ...

# %%
pd.read_csv('data/pt_data/Case_file.txt',delimiter='\t').head(5)
# Out:
#    patid  pracid  gender  birthyear   indexdate
# 0   1166     166       2       1917  02/05/2003
# 1   1633     633       2       1927  14/01/2011
# 2   2014      14       2       1922  04/04/2003
# 3   2477     477       2       1931  07/12/2009
# 4   3483     483       1       1920  20/06/2007

# %%
df = pd.read_csv('data/dicts/raw_pegasus_product.txt',delimiter='\t',encoding='latin-1',header=None)
df[df[3].str.contains('Zopiclone',na=False)][:10]
# note the importance of specifiying the encoding
# Out:
#           0         1        2   \
# 219       66  72416020  3857146
# 5334   30377  59785020      230
# 7269   14365  91009020     4344
# 11713  57937  71655020        1
# 12785  34777  59593020      174
# 17181  34823  59594020       58
# 19295  29219  59210020      620
# 20110  34372  63765020        5
# 20727  34897  65546020       22
# 24551  34612  60509020       13
#
#                                                       3          4   \
# 219                              Zopiclone 7.5mg tablets  Zopiclone
# 5334        Zopiclone 3.75mg tablets (Generics (UK) Ltd)  Zopiclone
# 7269                Zopiclone 3.75mg/5ml oral suspension  Zopiclone
# 11713  Zopiclone 3.75mg tablets (Almus Pharmaceutical...  Zopiclone
# 12785             Zopiclone 3.75mg tablets (Teva UK Ltd)  Zopiclone
# 17181              Zopiclone 7.5mg tablets (Teva UK Ltd)  Zopiclone
# 19295          Zopiclone 3.75mg tablets (Actavis UK Ltd)  Zopiclone
# ...

# %% [markdown]
# *medcode* is CRPD's version of the Read codes
