# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport data_processing
# %aimport codelists
# %aimport constants
# %aimport import_file

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:97% !important; }</style>"))
# Out:
# <style>.container { width:97% !important; }</style>

# %%
pd.set_option('display.max_columns', None)

# %%
from data_processing import *

# %%
from import_file import *

# %%
pd.options.display.max_rows = 1000

# %%
pt_features = pd.read_csv('data/pt_data/pt_features.csv',delimiter=',', parse_dates=['index_date','data_start','data_end'], infer_datetime_format=True)

# %%
pt_features
# Out:
#          patid  pracid  gender  birthyear index_date isCase  \
# 0     21880670     670       2       1931 2009-03-30   True
# 1      3846066      66       2       1931 2009-12-10   True
# 2      2904565     565       2       1943 2009-03-12   True
# 3      4537438     438       2       1939 2006-11-01   True
# 4      5924670     670       2       1935 2009-03-30   True
# 5      2859159     159       2       1927 2007-07-25   True
# 6     44248465     465       2       1935 2009-08-08   True
# 7      2245225     225       2       1933 2006-06-19   True
# 8      4628670     670       1       1927 2009-03-31   True
# 9      1829651     651       1       1921 2009-05-22   True
# 10    18325166     166       1       1931 2010-04-09   True
# 11     2075651     651       1       1935 2009-05-22   True
# 12     2963565     565       2       1924 2009-03-13   True
# 13    10139343     343       2       1922 2005-09-14   True
# 14     3672412     412       1       1934 2010-11-22   True
# ...

# %%
raw_pt = pd.read_csv('data/pt_data/raw_data/Extract_Patient_001.txt',delimiter='\t')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_pt
# Out:
#           patid    vmid  gender  yob  mob  marital  famnum  chsreg chsdate  \
# 0         57001    1682       1  132    0        2     730       2     NaN
# 1         60001    3405       1  124    0        6    1475       2     NaN
# 2        149001    3238       2  119    0        6    1398       2     NaN
# 3        364001   13436       2  137    0        2    6628       2     NaN
# 4        432001    4006       2  120    0        6    1726       2     NaN
# 5        519001    2697       2  127    0        6    1169       2     NaN
# 6        543001   18952       1  140    0        9    9586       2     NaN
# 7        558001    6221       2  137    0        6   10580       2     NaN
# 8        644001    9164       2  135    0        6    5462       2     NaN
# 9        663001    3049       2  118    0        6    2639       2     NaN
# 10       676001    6667       2  130    0        6    2801       2     NaN
# ...

# %%
pt_features_enhanced = pd.merge(pt_features,raw_pt[['patid','frd','crd','regstat','reggap','internal','tod','toreason','accept']],how='left')

# %%
pt_features_enhanced.sort_values(by='reggap',ascending=False)
# Out:
#          patid  pracid  gender  birthyear index_date isCase  \
# 3453  10637031      31       2       1926 2009-11-06   True
# 5690   2049031      31       1       1938 2010-12-20  False
# 6981    126031      31       2       1928 2009-04-27  False
# 7095  18173295     295       2       1927 2008-07-31  False
# 2379  11667411     411       1       1942 2008-05-15   True
# 4861   2869407     407       1       1935 2008-11-26  False
# 7804   5644226     226       1       1932 2010-12-13  False
# 2638  21523058      58       2       1933 2008-05-06   True
# 8333  11083410     410       2       1933 2008-01-14  False
# 3569  18681295     295       2       1939 2009-10-16   True
# 2403   7598195     195       2       1927 2008-02-04   True
# 2645   7471653     653       2       1926 2010-07-01   True
# 1295   9888109     109       1       1918 2008-07-04   True
# 7986   9327013      13       1       1937 2009-09-24  False
# 998    9001051      51       2       1928 2007-09-06   True
# ...

# %%
len(pt_features_enhanced[pt_features_enhanced['reggap']>100])
# Out:
# 88

# %%
pegmed = pd.read_csv('data/dicts/proc_pegasus_medical.csv',delimiter=',')

# %%
pegmed[pegmed['read term'].str.contains('sleep|insomnia*',na=False,case=False)].sort_values(by='clinical events',ascending=False)
# Out:
#         medcode readcode  clinical events  immunisation events  \
# 49117       750  R005200           587291                    0
# 80421      4537  1B1B.11           449676                    0
# 47755      8084  R005.00           188663                    0
# 6372      13173  663O.00           127337                    0
# 94784      4023  E274111           117094                    0
# 96971      7725  1B1Q.00            91558                    0
# 30061     38143  663O000            79953                    0
# 13395      2329  Fy0..00            66577                    0
# 23541      1244  R005000            61853                    0
# 38776      5921  Fy00.00            55901                    0
# 100756    21305  1B1B.00            51359                    0
# 88501      7416  663N.00            43757                    0
# 7995       7819  E274.00            38979                    0
# 20185      2506  R005311            26210                    0
# ...
